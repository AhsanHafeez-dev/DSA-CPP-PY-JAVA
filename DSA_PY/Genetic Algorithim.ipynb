# %%
import random
import numpy as np

# Define the distance matrix for the cities
# Example with 5 cities (symmetric matrix)
distance_matrix = np.array([
    [0, 2, 9, 10, 7],
    [2, 0, 6, 4, 3],
    [9, 6, 0, 8, 5],
    [10, 4, 8, 0, 6],
    [7, 3, 5, 6, 0]
])

# Parameters
population_size = 100
num_generations = 500
mutation_rate = 0.01

def create_route(num_cities):
    """ Create a random route (permutation of cities) """
    return random.sample(range(num_cities), num_cities)

def initial_population(pop_size, num_cities):
    """ Generate initial population """
    return [create_route(num_cities) for _ in range(pop_size)]

def fitness(route):
    """ Calculate the fitness of a route (total distance) """
    return sum(distance_matrix[route[i], route[i + 1]] for i in range(len(route) - 1)) + distance_matrix[route[-1], route[0]]

def rank_population(population):
    """ Rank population based on fitness """
    return sorted(population, key=lambda route: fitness(route))

def select_parents(population, elite_size):
    """ Select the best individuals to be parents (elitism) """
    return population[:elite_size]

def crossover(parent1, parent2):
    """ Ordered crossover """
    start, end = sorted(random.sample(range(len(parent1)), 2))
    child = [-1] * len(parent1)
    child[start:end] = parent1[start:end]
    
    p2_pointer = 0
    for i in range(len(parent1)):
        if child[i] == -1:
            while parent2[p2_pointer] in child:
                p2_pointer += 1
            child[i] = parent2[p2_pointer]
    
    return child

def mutate(route, mutation_rate):
    """ Swap mutation """
    for swapped in range(len(route)):
        if random.random() < mutation_rate:
            swap_with = int(random.random() * len(route))
            route[swapped], route[swap_with] = route[swap_with], route[swapped]
    return route

def next_generation(current_gen, elite_size, mutation_rate):
    """ Create next generation """
    ranked_population = rank_population(current_gen)
    parents = select_parents(ranked_population, elite_size)
    children = parents[:]
    
    num_new_children = len(current_gen) - len(parents)
    for _ in range(num_new_children):
        parent1, parent2 = random.sample(parents, 2)
        child = crossover(parent1, parent2)
        children.append(mutate(child, mutation_rate))
    
    return children

# Main Genetic Algorithm
def genetic_algorithm(num_cities, pop_size, num_gens, elite_size, mutation_rate):
    population = initial_population(pop_size, num_cities)
    
    for gen in range(num_gens):
        population = next_generation(population, elite_size, mutation_rate)
        best_route = rank_population(population)[0]
        best_distance = fitness(best_route)
        print(f"Generation {gen + 1}: Best Distance = {best_distance}")
    
    return best_route

# %%
# Example usage
best_route = genetic_algorithm(num_cities=5, pop_size=population_size, num_gens=num_generations, elite_size=20, mutation_rate=mutation_rate)
print(f"Best Route: {best_route}")
# Out:
# Generation 1: Best Distance = 26
# Generation 2: Best Distance = 26
# Generation 3: Best Distance = 26
# Generation 4: Best Distance = 26
# Generation 5: Best Distance = 26
# Generation 6: Best Distance = 26
# Generation 7: Best Distance = 26
# Generation 8: Best Distance = 26
# Generation 9: Best Distance = 26
# Generation 10: Best Distance = 26
# Generation 11: Best Distance = 26
# Generation 12: Best Distance = 26
# Generation 13: Best Distance = 26
# Generation 14: Best Distance = 26
# Generation 15: Best Distance = 26
# Generation 16: Best Distance = 26
# Generation 17: Best Distance = 26
# Generation 18: Best Distance = 26
# Generation 19: Best Distance = 26
# Generation 20: Best Distance = 26
# Generation 21: Best Distance = 26
# Generation 22: Best Distance = 26
# Generation 23: Best Distance = 26
# Generation 24: Best Distance = 26
# Generation 25: Best Distance = 26
# Generation 26: Best Distance = 26
# Generation 27: Best Distance = 26
# Generation 28: Best Distance = 26
# Generation 29: Best Distance = 26
# Generation 30: Best Distance = 26
# Generation 31: Best Distance = 26
# Generation 32: Best Distance = 26
# Generation 33: Best Distance = 26
# Generation 34: Best Distance = 26
# Generation 35: Best Distance = 26
# Generation 36: Best Distance = 26
# Generation 37: Best Distance = 26
# Generation 38: Best Distance = 26
# Generation 39: Best Distance = 26
# Generation 40: Best Distance = 26
# Generation 41: Best Distance = 26
# Generation 42: Best Distance = 26
# Generation 43: Best Distance = 26
# Generation 44: Best Distance = 26
# Generation 45: Best Distance = 26
# Generation 46: Best Distance = 26
# Generation 47: Best Distance = 26
# Generation 48: Best Distance = 26
# Generation 49: Best Distance = 26
# Generation 50: Best Distance = 26
# Generation 51: Best Distance = 26
# Generation 52: Best Distance = 26
# Generation 53: Best Distance = 26
# Generation 54: Best Distance = 26
# Generation 55: Best Distance = 26
# Generation 56: Best Distance = 26
# Generation 57: Best Distance = 26
# Generation 58: Best Distance = 26
# Generation 59: Best Distance = 26
# Generation 60: Best Distance = 26
# Generation 61: Best Distance = 26
# Generation 62: Best Distance = 26
# Generation 63: Best Distance = 26
# Generation 64: Best Distance = 26
# Generation 65: Best Distance = 26
# Generation 66: Best Distance = 26
# Generation 67: Best Distance = 26
# Generation 68: Best Distance = 26
# Generation 69: Best Distance = 26
# Generation 70: Best Distance = 26
# Generation 71: Best Distance = 26
# Generation 72: Best Distance = 26
# Generation 73: Best Distance = 26
# Generation 74: Best Distance = 26
# Generation 75: Best Distance = 26
# Generation 76: Best Distance = 26
# Generation 77: Best Distance = 26
# Generation 78: Best Distance = 26
# Generation 79: Best Distance = 26
# Generation 80: Best Distance = 26
# Generation 81: Best Distance = 26
# Generation 82: Best Distance = 26
# Generation 83: Best Distance = 26
# Generation 84: Best Distance = 26
# Generation 85: Best Distance = 26
# Generation 86: Best Distance = 26
# Generation 87: Best Distance = 26
# Generation 88: Best Distance = 26
# Generation 89: Best Distance = 26
# Generation 90: Best Distance = 26
# Generation 91: Best Distance = 26
# Generation 92: Best Distance = 26
# Generation 93: Best Distance = 26
# Generation 94: Best Distance = 26
# Generation 95: Best Distance = 26
# Generation 96: Best Distance = 26
# Generation 97: Best Distance = 26
# Generation 98: Best Distance = 26
# Generation 99: Best Distance = 26
# Generation 100: Best Distance = 26
# Generation 101: Best Distance = 26
# Generation 102: Best Distance = 26
# Generation 103: Best Distance = 26
# Generation 104: Best Distance = 26
# Generation 105: Best Distance = 26
# Generation 106: Best Distance = 26
# Generation 107: Best Distance = 26
# Generation 108: Best Distance = 26
# Generation 109: Best Distance = 26
# Generation 110: Best Distance = 26
# Generation 111: Best Distance = 26
# Generation 112: Best Distance = 26
# Generation 113: Best Distance = 26
# Generation 114: Best Distance = 26
# Generation 115: Best Distance = 26
# Generation 116: Best Distance = 26
# Generation 117: Best Distance = 26
# Generation 118: Best Distance = 26
# Generation 119: Best Distance = 26
# Generation 120: Best Distance = 26
# Generation 121: Best Distance = 26
# Generation 122: Best Distance = 26
# Generation 123: Best Distance = 26
# Generation 124: Best Distance = 26
# Generation 125: Best Distance = 26
# Generation 126: Best Distance = 26
# Generation 127: Best Distance = 26
# Generation 128: Best Distance = 26
# Generation 129: Best Distance = 26
# Generation 130: Best Distance = 26
# Generation 131: Best Distance = 26
# Generation 132: Best Distance = 26
# Generation 133: Best Distance = 26
# Generation 134: Best Distance = 26
# Generation 135: Best Distance = 26
# Generation 136: Best Distance = 26
# Generation 137: Best Distance = 26
# Generation 138: Best Distance = 26
# Generation 139: Best Distance = 26
# Generation 140: Best Distance = 26
# Generation 141: Best Distance = 26
# Generation 142: Best Distance = 26
# Generation 143: Best Distance = 26
# Generation 144: Best Distance = 26
# Generation 145: Best Distance = 26
# Generation 146: Best Distance = 26
# Generation 147: Best Distance = 26
# Generation 148: Best Distance = 26
# Generation 149: Best Distance = 26
# Generation 150: Best Distance = 26
# Generation 151: Best Distance = 26
# Generation 152: Best Distance = 26
# Generation 153: Best Distance = 26
# Generation 154: Best Distance = 26
# Generation 155: Best Distance = 26
# Generation 156: Best Distance = 26
# Generation 157: Best Distance = 26
# Generation 158: Best Distance = 26
# Generation 159: Best Distance = 26
# Generation 160: Best Distance = 26
# Generation 161: Best Distance = 26
# Generation 162: Best Distance = 26
# Generation 163: Best Distance = 26
# Generation 164: Best Distance = 26
# Generation 165: Best Distance = 26
# Generation 166: Best Distance = 26
# Generation 167: Best Distance = 26
# Generation 168: Best Distance = 26
# Generation 169: Best Distance = 26
# Generation 170: Best Distance = 26
# Generation 171: Best Distance = 26
# Generation 172: Best Distance = 26
# Generation 173: Best Distance = 26
# Generation 174: Best Distance = 26
# Generation 175: Best Distance = 26
# Generation 176: Best Distance = 26
# Generation 177: Best Distance = 26
# Generation 178: Best Distance = 26
# Generation 179: Best Distance = 26
# Generation 180: Best Distance = 26
# Generation 181: Best Distance = 26
# Generation 182: Best Distance = 26
# Generation 183: Best Distance = 26
# Generation 184: Best Distance = 26
# Generation 185: Best Distance = 26
# Generation 186: Best Distance = 26
# Generation 187: Best Distance = 26
# Generation 188: Best Distance = 26
# Generation 189: Best Distance = 26
# Generation 190: Best Distance = 26
# Generation 191: Best Distance = 26
# Generation 192: Best Distance = 26
# Generation 193: Best Distance = 26
# Generation 194: Best Distance = 26
# Generation 195: Best Distance = 26
# Generation 196: Best Distance = 26
# Generation 197: Best Distance = 26
# Generation 198: Best Distance = 26
# Generation 199: Best Distance = 26
# Generation 200: Best Distance = 26
# Generation 201: Best Distance = 26
# Generation 202: Best Distance = 26
# Generation 203: Best Distance = 26
# Generation 204: Best Distance = 26
# Generation 205: Best Distance = 26
# Generation 206: Best Distance = 26
# Generation 207: Best Distance = 26
# Generation 208: Best Distance = 26
# Generation 209: Best Distance = 26
# Generation 210: Best Distance = 26
# Generation 211: Best Distance = 26
# Generation 212: Best Distance = 26
# Generation 213: Best Distance = 26
# Generation 214: Best Distance = 26
# Generation 215: Best Distance = 26
# Generation 216: Best Distance = 26
# Generation 217: Best Distance = 26
# Generation 218: Best Distance = 26
# Generation 219: Best Distance = 26
# Generation 220: Best Distance = 26
# Generation 221: Best Distance = 26
# Generation 222: Best Distance = 26
# Generation 223: Best Distance = 26
# Generation 224: Best Distance = 26
# Generation 225: Best Distance = 26
# Generation 226: Best Distance = 26
# Generation 227: Best Distance = 26
# Generation 228: Best Distance = 26
# Generation 229: Best Distance = 26
# Generation 230: Best Distance = 26
# Generation 231: Best Distance = 26
# Generation 232: Best Distance = 26
# Generation 233: Best Distance = 26
# Generation 234: Best Distance = 26
# Generation 235: Best Distance = 26
# Generation 236: Best Distance = 26
# Generation 237: Best Distance = 26
# Generation 238: Best Distance = 26
# Generation 239: Best Distance = 26
# Generation 240: Best Distance = 26
# Generation 241: Best Distance = 26
# Generation 242: Best Distance = 26
# Generation 243: Best Distance = 26
# Generation 244: Best Distance = 26
# Generation 245: Best Distance = 26
# Generation 246: Best Distance = 26
# Generation 247: Best Distance = 26
# Generation 248: Best Distance = 26
# Generation 249: Best Distance = 26
# Generation 250: Best Distance = 26
# Generation 251: Best Distance = 26
# Generation 252: Best Distance = 26
# Generation 253: Best Distance = 26
# Generation 254: Best Distance = 26
# Generation 255: Best Distance = 26
# Generation 256: Best Distance = 26
# Generation 257: Best Distance = 26
# Generation 258: Best Distance = 26
# Generation 259: Best Distance = 26
# Generation 260: Best Distance = 26
# Generation 261: Best Distance = 26
# Generation 262: Best Distance = 26
# Generation 263: Best Distance = 26
# Generation 264: Best Distance = 26
# Generation 265: Best Distance = 26
# Generation 266: Best Distance = 26
# Generation 267: Best Distance = 26
# Generation 268: Best Distance = 26
# Generation 269: Best Distance = 26
# Generation 270: Best Distance = 26
# Generation 271: Best Distance = 26
# Generation 272: Best Distance = 26
# Generation 273: Best Distance = 26
# Generation 274: Best Distance = 26
# Generation 275: Best Distance = 26
# Generation 276: Best Distance = 26
# Generation 277: Best Distance = 26
# Generation 278: Best Distance = 26
# Generation 279: Best Distance = 26
# Generation 280: Best Distance = 26
# Generation 281: Best Distance = 26
# Generation 282: Best Distance = 26
# Generation 283: Best Distance = 26
# Generation 284: Best Distance = 26
# Generation 285: Best Distance = 26
# Generation 286: Best Distance = 26
# Generation 287: Best Distance = 26
# Generation 288: Best Distance = 26
# Generation 289: Best Distance = 26
# Generation 290: Best Distance = 26
# Generation 291: Best Distance = 26
# Generation 292: Best Distance = 26
# Generation 293: Best Distance = 26
# Generation 294: Best Distance = 26
# Generation 295: Best Distance = 26
# Generation 296: Best Distance = 26
# Generation 297: Best Distance = 26
# Generation 298: Best Distance = 26
# Generation 299: Best Distance = 26
# Generation 300: Best Distance = 26
# Generation 301: Best Distance = 26
# Generation 302: Best Distance = 26
# Generation 303: Best Distance = 26
# Generation 304: Best Distance = 26
# Generation 305: Best Distance = 26
# Generation 306: Best Distance = 26
# Generation 307: Best Distance = 26
# Generation 308: Best Distance = 26
# Generation 309: Best Distance = 26
# Generation 310: Best Distance = 26
# Generation 311: Best Distance = 26
# Generation 312: Best Distance = 26
# Generation 313: Best Distance = 26
# Generation 314: Best Distance = 26
# Generation 315: Best Distance = 26
# Generation 316: Best Distance = 26
# Generation 317: Best Distance = 26
# Generation 318: Best Distance = 26
# Generation 319: Best Distance = 26
# Generation 320: Best Distance = 26
# Generation 321: Best Distance = 26
# Generation 322: Best Distance = 26
# Generation 323: Best Distance = 26
# Generation 324: Best Distance = 26
# Generation 325: Best Distance = 26
# Generation 326: Best Distance = 26
# Generation 327: Best Distance = 26
# Generation 328: Best Distance = 26
# Generation 329: Best Distance = 26
# Generation 330: Best Distance = 26
# Generation 331: Best Distance = 26
# Generation 332: Best Distance = 26
# Generation 333: Best Distance = 26
# Generation 334: Best Distance = 26
# Generation 335: Best Distance = 26
# Generation 336: Best Distance = 26
# Generation 337: Best Distance = 26
# Generation 338: Best Distance = 26
# Generation 339: Best Distance = 26
# Generation 340: Best Distance = 26
# Generation 341: Best Distance = 26
# Generation 342: Best Distance = 26
# Generation 343: Best Distance = 26
# Generation 344: Best Distance = 26
# Generation 345: Best Distance = 26
# Generation 346: Best Distance = 26
# Generation 347: Best Distance = 26
# Generation 348: Best Distance = 26
# Generation 349: Best Distance = 26
# Generation 350: Best Distance = 26
# Generation 351: Best Distance = 26
# Generation 352: Best Distance = 26
# Generation 353: Best Distance = 26
# Generation 354: Best Distance = 26
# Generation 355: Best Distance = 26
# Generation 356: Best Distance = 26
# Generation 357: Best Distance = 26
# Generation 358: Best Distance = 26
# Generation 359: Best Distance = 26
# Generation 360: Best Distance = 26
# Generation 361: Best Distance = 26
# Generation 362: Best Distance = 26
# Generation 363: Best Distance = 26
# Generation 364: Best Distance = 26
# Generation 365: Best Distance = 26
# Generation 366: Best Distance = 26
# Generation 367: Best Distance = 26
# Generation 368: Best Distance = 26
# Generation 369: Best Distance = 26
# Generation 370: Best Distance = 26
# Generation 371: Best Distance = 26
# Generation 372: Best Distance = 26
# Generation 373: Best Distance = 26
# Generation 374: Best Distance = 26
# Generation 375: Best Distance = 26
# Generation 376: Best Distance = 26
# Generation 377: Best Distance = 26
# Generation 378: Best Distance = 26
# Generation 379: Best Distance = 26
# Generation 380: Best Distance = 26
# Generation 381: Best Distance = 26
# Generation 382: Best Distance = 26
# Generation 383: Best Distance = 26
# Generation 384: Best Distance = 26
# Generation 385: Best Distance = 26
# Generation 386: Best Distance = 26
# Generation 387: Best Distance = 26
# Generation 388: Best Distance = 26
# Generation 389: Best Distance = 26
# Generation 390: Best Distance = 26
# Generation 391: Best Distance = 26
# Generation 392: Best Distance = 26
# Generation 393: Best Distance = 26
# Generation 394: Best Distance = 26
# Generation 395: Best Distance = 26
# Generation 396: Best Distance = 26
# Generation 397: Best Distance = 26
# Generation 398: Best Distance = 26
# Generation 399: Best Distance = 26
# Generation 400: Best Distance = 26
# Generation 401: Best Distance = 26
# Generation 402: Best Distance = 26
# Generation 403: Best Distance = 26
# Generation 404: Best Distance = 26
# Generation 405: Best Distance = 26
# Generation 406: Best Distance = 26
# Generation 407: Best Distance = 26
# Generation 408: Best Distance = 26
# Generation 409: Best Distance = 26
# Generation 410: Best Distance = 26
# Generation 411: Best Distance = 26
# Generation 412: Best Distance = 26
# Generation 413: Best Distance = 26
# Generation 414: Best Distance = 26
# Generation 415: Best Distance = 26
# Generation 416: Best Distance = 26
# Generation 417: Best Distance = 26
# Generation 418: Best Distance = 26
# Generation 419: Best Distance = 26
# Generation 420: Best Distance = 26
# Generation 421: Best Distance = 26
# Generation 422: Best Distance = 26
# Generation 423: Best Distance = 26
# Generation 424: Best Distance = 26
# Generation 425: Best Distance = 26
# Generation 426: Best Distance = 26
# Generation 427: Best Distance = 26
# Generation 428: Best Distance = 26
# Generation 429: Best Distance = 26
# Generation 430: Best Distance = 26
# Generation 431: Best Distance = 26
# Generation 432: Best Distance = 26
# Generation 433: Best Distance = 26
# Generation 434: Best Distance = 26
# Generation 435: Best Distance = 26
# Generation 436: Best Distance = 26
# Generation 437: Best Distance = 26
# Generation 438: Best Distance = 26
# Generation 439: Best Distance = 26
# Generation 440: Best Distance = 26
# Generation 441: Best Distance = 26
# Generation 442: Best Distance = 26
# Generation 443: Best Distance = 26
# Generation 444: Best Distance = 26
# Generation 445: Best Distance = 26
# Generation 446: Best Distance = 26
# Generation 447: Best Distance = 26
# Generation 448: Best Distance = 26
# Generation 449: Best Distance = 26
# Generation 450: Best Distance = 26
# Generation 451: Best Distance = 26
# Generation 452: Best Distance = 26
# Generation 453: Best Distance = 26
# Generation 454: Best Distance = 26
# Generation 455: Best Distance = 26
# Generation 456: Best Distance = 26
# Generation 457: Best Distance = 26
# Generation 458: Best Distance = 26
# Generation 459: Best Distance = 26
# Generation 460: Best Distance = 26
# Generation 461: Best Distance = 26
# Generation 462: Best Distance = 26
# Generation 463: Best Distance = 26
# Generation 464: Best Distance = 26
# Generation 465: Best Distance = 26
# Generation 466: Best Distance = 26
# Generation 467: Best Distance = 26
# Generation 468: Best Distance = 26
# Generation 469: Best Distance = 26
# Generation 470: Best Distance = 26
# Generation 471: Best Distance = 26
# Generation 472: Best Distance = 26
# Generation 473: Best Distance = 26
# Generation 474: Best Distance = 26
# Generation 475: Best Distance = 26
# Generation 476: Best Distance = 26
# Generation 477: Best Distance = 26
# Generation 478: Best Distance = 26
# Generation 479: Best Distance = 26
# Generation 480: Best Distance = 26
# Generation 481: Best Distance = 26
# Generation 482: Best Distance = 26
# Generation 483: Best Distance = 26
# Generation 484: Best Distance = 26
# Generation 485: Best Distance = 26
# Generation 486: Best Distance = 26
# Generation 487: Best Distance = 26
# Generation 488: Best Distance = 26
# Generation 489: Best Distance = 26
# Generation 490: Best Distance = 26
# Generation 491: Best Distance = 26
# Generation 492: Best Distance = 26
# Generation 493: Best Distance = 26
# Generation 494: Best Distance = 26
# Generation 495: Best Distance = 26
# Generation 496: Best Distance = 26
# Generation 497: Best Distance = 26
# Generation 498: Best Distance = 26
# Generation 499: Best Distance = 26
# Generation 500: Best Distance = 26
# Best Route: [1, 3, 4, 2, 0]

# %%
import random

# Define the cities and their coordinates
cities = {
    'Rawalpindi': (33.6844, 73.0479),
    'Peshawar': (34.0151, 71.5249),
    'Kohat': (33.5568, 71.4493),
    'Lahore': (31.5497, 74.3436),
    'Karachi': (24.8607, 67.0011),
    'Chakwal': (32.9333, 72.85),
    'Islamabad': (33.6844, 73.0479),
    'Faisalabad': (31.4504, 73.1350)
}

# Calculate the Euclidean distance between two cities
def calculate_distance(city1, city2):
    return ((city1[0] - city2[0])**2 + (city1[1] - city2[1])**2) ** 0.5

# Fitness function: total distance of the path
def fitness(path):
    total_distance = 0
    for i in range(len(path) - 1):
        total_distance += calculate_distance(cities[path[i]], cities[path[i+1]])
    total_distance += calculate_distance(cities[path[-1]], cities[path[0]])  # return to start
    return total_distance

# Create initial population
def create_population(cities, size):
    population = []
    for _ in range(size):
        individual = list(cities.keys())
        individual.remove('Rawalpindi')
        random.shuffle(individual)
        individual = ['Rawalpindi'] + individual  # Start from Rawalpindi
        population.append(individual)
    return population

# Select individuals for mating
def select(population, fitnesses, k=3):
    selected = random.choices(population, weights=[1/f for f in fitnesses], k=k)
    return min(selected, key=lambda ind: fitness(ind))

# Crossover between two parents
def crossover(parent1, parent2):
    start, end = sorted(random.sample(range(1, len(parent1)), 2))
    child = [None] * len(parent1)
    child[start:end] = parent1[start:end]
    pointer = end
    for city in parent2:
        if city not in child:
            while child[pointer % len(child)] is not None:
                pointer += 1
            child[pointer % len(child)] = city
    return child

# Mutate an individual
def mutate(individual, mutation_rate=0.01):
    for i in range(1, len(individual)):
        if random.random() < mutation_rate:
            j = random.randint(1, len(individual) - 1)
            individual[i], individual[j] = individual[j], individual[i]

# Genetic Algorithm
def genetic_algorithm(cities, population_size=100, generations=500, mutation_rate=0.01):
    population = create_population(cities, population_size)
    for _ in range(generations):
        fitnesses = [fitness(ind) for ind in population]
        new_population = []
        for _ in range(population_size):
            parent1 = select(population, fitnesses)
            parent2 = select(population, fitnesses)
            child = crossover(parent1, parent2)
            mutate(child, mutation_rate)
            new_population.append(child)
        population = new_population
    best_individual = min(population, key=lambda ind: fitness(ind))
    return best_individual, fitness(best_individual)

# %%
# Running the algorithm
best_path, best_distance = genetic_algorithm(cities,generations=3)
print("Best path     :", best_path)
print("Total distance:", best_distance)
# Out:
# Best path     : ['Islamabad', 'Rawalpindi', 'Chakwal', 'Lahore', 'Faisalabad', 'Karachi', 'Kohat', 'Peshawar']
# Total distance: 24.818813452909094

# %%
user=[]

# %%
if user:
    print("true")
else:
    print("false")
# Out:
# false

# %%
#not a good implementaion just for demonstrationn
class Graphs:    
    def __init__(self):
        self.g={}
    def add_edge(self,src,dest,weight):
        if dest not in self.g[src]:
            self.g[src][dest]= weight
    def add_node(self,src):
        self.g[src]={}
    def __str__(self):
        return str(self.g)

# %%
from pprint import pprint
import numpy as np
np.random.seed(1337)

# %%
cities=["peshawar","kohat","quetta","rawalpandi","islamabad","faislabad","chakwal","lahore","karachi"]    #chromosomes
cities2=["peshawar","islamabad","faislabad","chakwal","lahore","karachi","kohat","quetta","rawalpandi"]    #chromosomes

# %%
g=Graphs()
t=1
for i in range(len(cities)):
    g.add_node(cities[i])
    for j in range(len(cities)):
        if j!=i:
            g.add_edge(cities[i],cities[j],t))
            t+=1
# Out:
#   File "C:\Users\ok\AppData\Local\Temp\ipykernel_3416\2416670503.py", line 7
#     g.add_edge(cities[i],cities[j],t))
#                                      ^
# SyntaxError: unmatched ')'

# %%
# pprint(g.__str__())

# %%
def fitness_function(chromosome,g):
    path=0
    start=chromosome[0]
    for individual in chromosome:
        if individual!=start:
            path+=g.g[start][individual]
            start=individual
    return path

# %%
def crossover(chromosome1,chromosome2):
    
    first_half=chromosome1[: len(chromosome1) // 2 ]
    
    second_half =[item for item in chromosome2 if item not in first_half]
    breed1=first_half+second_half
    
    first_half=chromosome2[: len(chromosome2) // 2 ]
    second_half =[item for item in chromosome1 if item not in first_half]
    breed2=first_half+second_half
    
    breed3,breed4=breed1,breed2
    breed3[1],breed3[-1]=breed3[-1],breed3[1]
    breed4[1],breed4[-1]=breed4[-1],breed4[1]
    return [breed1,breed2,breed3,breed4]

# %%
def algorithim(chromosome1,chromosome2,g,n=10):
    p=new_chromosomes=[chromosome1,chromosome2]
    print(fitness_function(p[0],g ) )
    print(fitness_function(p[1] , g ) )
    for i in range(n):
        f=[]        
        for individual in new_chromosomes:
            f1=fitness_function(individual,g)
            f.append(f1)
            print(f"{individual} -> Fitness: {f1}")
        new_chromosomes=crossover(p[0],p[1])
        print("\nNew Chromosomes after Crossover:")
        for c in new_chromosomes:
            print(f"{c} -> Fitness: {fitness_function(c, g)}")
        max1,max2 = sorted(range(len(f)), key=lambda i: f[i], reverse=True)[:2]
        p[0],p[1]=new_chromosomes[max1],new_chromosomes[max2]
    print(fitness_function(p[0],g ))
    print(fitness_function(p[0] , g ))

# %%
algorithim(cities,cities2,g)

# %%
class Graphs:    
    def __init__(self):
        self.g = {}

    def add_edge(self, src, dest, weight):
        if src not in self.g:
            self.g[src] = {}
        self.g[src][dest] = weight

    def add_node(self, src):
        if src not in self.g:
            self.g[src] = {}

    def __str__(self):
        return str(self.g)

def fitness_function(chromosome, g):
    path = 0
    start = chromosome[0]
    for individual in chromosome[1:]:
        path += g.g[start].get(individual, float('inf'))
        start = individual
    return path

def crossover(chromosome1, chromosome2):
    first_half = chromosome1[:len(chromosome1) // 2]
    second_half = [item for item in chromosome2 if item not in first_half]
    breed1 = first_half + second_half

    first_half = chromosome2[:len(chromosome2) // 2]
    second_half = [item for item in chromosome1 if item not in first_half]
    breed2 = first_half + second_half

    # Swapping first and last elements to create additional variations
    breed3, breed4 = breed1[:], breed2[:]
    breed3[0], breed3[-1] = breed3[-1], breed3[0]
    breed4[0], breed4[-1] = breed4[-1], breed4[0]

    return [breed1, breed2, breed3, breed4]

def algorithm(cities1, cities2, g):
    chromosomes = [cities1, cities2]
    print("Initial Chromosomes:")
    for c in chromosomes:
        print(f"{c} -> Fitness: {fitness_function(c, g)}")

    # Perform crossover
    new_chromosomes = crossover(cities1, cities2)
    print("\nNew Chromosomes after Crossover:")
    for c in new_chromosomes:
        print(f"{c} -> Fitness: {fitness_function(c, g)}")

# Define cities and graph
cities = ["peshawar", "kohat", "quetta", "rawalpandi", "islamabad", "faislabad", "chakwal", "lahore", "karachi"]
cities2 = ["peshawar", "islamabad", "faislabad", "chakwal", "lahore", "karachi", "kohat", "quetta", "rawalpandi"]

g = Graphs()
t = 1
for i in range(len(cities)):
    g.add_node(cities[i])
    for j in range(len(cities)):
        if j != i:
            g.add_edge(cities[i], cities[j], t)
            t += 1

algorithm(cities, cities2, g)
